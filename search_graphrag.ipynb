# %%
{
    1.99: 4
}
# Out:
# {1.99: 4}

# %%
import torch
from graphrag_for_all.llm.create import get_send_fn
from graphrag_for_all.search.searcher import Searcher

print(torch.cuda.is_available())
# Out:
# True

# %%
"Based on the provided report, I will speculate the values for the keywords listed in the 'Data Type' JSON object.\n\n## Shortness of breath\nSpeculated value: true\nReasoning: Shortness of breath is a symptom that can be present in various conditions, including pneumonia, heart failure, and other respiratory conditions. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Fatigue\nSpeculated value: false\nReasoning: Fatigue is not a symptom that is typically associated with pneumonia or heart failure. While it can be a symptom in some cases, it is not a common symptom that is usually present in these conditions.\n\n## Swelling in the legs and feet\nSpeculated value: true\nReasoning: Swelling in the legs and feet can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Chest pain\nSpeculated value: true\nReasoning: Chest pain is a symptom that can be present in various conditions, including pneumonia, heart failure, and other respiratory conditions. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Palpitations\nSpeculated value: true\nReasoning: Palpitations can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Coughing up blood\nSpeculated value: true\nReasoning: Coughing up blood can be a symptom of various conditions, including pneumonia, heart failure, and other respiratory conditions. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Fluid buildup in the lungs\nSpeculated value: true\nReasoning: Fluid buildup in the lungs can be a symptom of various conditions, including pneumonia, heart failure, and other respiratory conditions. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Confusion\nSpeculated value: false\nReasoning: Confusion is not a symptom that is typically associated with pneumonia or heart failure. While it can be a symptom in some cases, it is not a common symptom that is usually present in these conditions.\n\n## Loss of appetite\nSpeculated value: false\nReasoning: Loss of appetite is not a symptom that is typically associated with pneumonia or heart failure. While it can be a symptom in some cases, it is not a common symptom that is usually present in these conditions.\n\n## Pericardial effusion\nSpeculated value: true\nReasoning: Pericardial effusion is a condition that can be associated with various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Cardiomegaly\nSpeculated value: true\nReasoning: Cardiomegaly is a condition that can be associated with various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Increased cardiothoracic ratio\nSpeculated value: true\nReasoning: Increased cardiothoracic ratio is a symptom that can be present in various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Anterior mediastinal mass\nSpeculated value: true\nReasoning: An anterior mediastinal mass can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Prominent epicardial fat pad\nSpeculated value: true\nReasoning: A prominent epicardial fat pad can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Elevated pericardial fluid levels (mL)\nSpeculated value: true\nReasoning: Elevated pericardial fluid levels can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Increased pericardial fluid protein levels (mg/dL)\nSpeculated value: true\nReasoning: Increased pericardial fluid protein levels can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Presence of pericardial fluid cells\nSpeculated value: true\nReasoning: The presence of pericardial fluid cells can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Radiographic images showing an increased cardiothoracic ratio\nSpeculated value: true\nReasoning: Radiographic images showing an increased cardiothoracic ratio can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Measurements of cardiac diameter and thoracic diameter (cm)\nSpeculated value: true\nReasoning: Measurements of cardiac diameter and thoracic diameter can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Measurements of cardiac dimensions (cm)\nSpeculated value: true\nReasoning: Measurements of cardiac dimensions can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## White Blood Cell Count (cells/\\u03bcL)\nSpeculated value: true\nReasoning: A white blood cell count can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## C-Reactive Protein (CRP) levels (mg/L)\nSpeculated value: true\nReasoning: C-Reactive Protein (CRP) levels can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Procalcitonin levels (ng/mL)\nSpeculated value: true\nReasoning: Procalcitonin levels can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Lung Volume (L)\nSpeculated value: true\nReasoning: Lung volume can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Diffusing Capacity (mL/min/mmHg)\nSpeculated value: true\nReasoning: Diffusing Capacity (mL/min/mmHg) can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Gas Exchange (mL/min/mmHg)\nSpeculated value: true\nReasoning: Gas Exchange (mL/min/mmHg) can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Arterial Blood Gas (ABG) analysis\nSpeculated value: true\nReasoning: An Arterial Blood Gas (ABG) analysis can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Complete Blood Count (CBC)\nSpeculated value: true\nReasoning: A Complete Blood Count (CBC) can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Electrolyte Panel\nSpeculated value: true\nReasoning: An Electrolyte Panel can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n##
be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Difficulty breathing\nSpeculated value: true\nReasoning: Difficulty breathing can be a symptom of various conditions, including pneumonia and heart failure. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Wheezing\nSpeculated value: true\nReasoning: Wheezing can be a symptom of various conditions, including pneumonia and heart failure. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Age (years)\nSpeculated value: true\nReasoning: Age (years) can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Oxygen levels (mmHg)\nSpeculated value: true\nReasoning: Oxygen levels (mmHg) can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Body Temperature (\\u00b0C)\nSpeculated value: true\nReasoning: Body Temperature (\\u00b0C) can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Breathing Rate (breaths/min)\nSpeculated value: true\nReasoning: Breathing Rate (breaths/min) can be a symptom of various conditions, including infection and inflammation. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Cardiothoracic ratio\nSpeculated value: true\nReasoning: Cardiothoracic ratio can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Lung expansion\nSpeculated value: true\nReasoning: Lung expansion can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Pleural effusion risk factors (1-5)\nSpeculated value: true\nReasoning: Pleural effusion risk factors (1-5) can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several conditions, making it a reasonable speculation.\n\n## Pleural disease risk factors (1-10)\nSpeculated value: true\nReasoning: Pleural disease risk factors (1-10) can be a symptom of various conditions, including heart failure and fluid buildup in the lungs. It is a common symptom that can be associated with several"

# %%
### Prameters to play with ###

llm_source = "openai"
model_name = "gpt-3.5-turbo"
knowledge_graph_dir = "./combined_index_results/graphrag/index_graphrag_llama3v1_combined_top_1/"


# llm_source = "huggingface"
# model_name = "meta-llama/Meta-Llama-3.1-8B-Instruct"
# knowledge_graph_dir = "./index_results/graphrag/atelectasis_top_1_llama3_1/"
##############################

searcher = Searcher(
    input_dir=knowledge_graph_dir,
    send_to=get_send_fn(source=llm_source, model_name=model_name),
    community_level=1,
)
# Out:
# f:\GitHub\rag-aug\graphrag_for_all\search\read.py:1099: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_df["community"] = entity_df["community"].fillna(-1)
# f:\GitHub\rag-aug\graphrag_for_all\search\read.py:1100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_df["community"] = entity_df["community"].astype(int)

# %%
result.response
# Out:
# 'I am sorry but I am unable to answer this question given the provided data.'

# %%
result = searcher.search(
    query="What are symptoms of atelectasis?",
)
# Out:
# Computing community weights...
# Exception in _map_response_single_batch

# %%
print(result.context_text[0])
# Out:
# id|title|occurrence weight|content|rank
# 7|Atelectasis and Pneumothorax Community|1.0|"# Atelectasis and Pneumothorax Community
#
# The community revolves around Atelectasis and Pneumothorax, two conditions that are closely related and often occur together. Atelectasis is a condition where a part of the lung collapses or does not expand properly, while Pneumothorax is a condition involving air in the pleural space. The two conditions are often linked, with Atelectasis being a potential cause of Pneumothorax, and Pneumothorax being a potential cause of Atelectasis.
#
# ## Atelectasis as a central entity
#
# Atelectasis is the central entity in this community, serving as a condition that can cause Pneumothorax and other related conditions. This relationship is supported by multiple data references [Data: Relationships (18, 47, 50, 129, 126); Entities (35)].
#
# ## Pneumothorax as a related condition
#
# ...

# %%
result.context_data["reports"]
# Out:
#     id                                              title  occurrence weight  \
# 0    7             Atelectasis and Pneumothorax Community           1.000000
# 1   12              Pneumonia and Heart Failure Community           0.833333
# 2    2           Cardiac Silhouette Enlargement Community           0.833333
# 3    5                             Lung Disease Community           0.666667
# 4    8  LEFT LOWER LOBE COLLAPSE and RIGHT UPPER LOBE ...           0.500000
# 5   10    PLEURAL EFFUSION and PNEUMOPERITONEUM Community           0.500000
# 6    6                            Lung Diseases Community           0.333333
# 7   13                  Pulmonary Consolidation Community           0.333333
# 8   14  Pulmonary Tuberculosis and Postsurgical Atelec...           0.333333
# 9    3                             Pericarditis Community           0.166667
# 10   9  Infant Respiratory Distress Syndrome and Surfa...           0.166667
# ...

# %%
# inspect number of LLM calls and tokens
print(f"LLM calls: {result.llm_calls}. LLM tokens: {result.prompt_tokens}")
# Out:
# LLM calls: 1. LLM tokens: 9064
