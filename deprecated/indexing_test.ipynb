# %%
import os

wiki_path = os.path.isfile(os.path.join(retriever.saving_dir, f"wiki_atelectasis.pk"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
# ----> 3 wiki_path = os.path.join(retriever.saving_dir, f"wiki_atelectasis.pk")
#
# NameError: name 'retriever' is not defined

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False

# %%
# def _resolve_inputs( -> how the input data is gained.
# steps inside Worflow.schema['steps']

# %%
from retreivers.radiowiki import RadioWikiRetriever
retriever = RadioWikiRetriever()
docs = retriever.request("atelectasis")
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File c:\Users\chihcheH\AppData\Local\anaconda3\envs\pytorch\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File c:\Users\chihcheH\AppData\Local\anaconda3\envs\pytorch\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
# ...

# %%
from index_pipeline import lc_doc_to_df

dataset = lc_doc_to_df(docs)
# pipleline creating functions in orders.
# create_base_documents
# create_final_documents

# %%
class PipelineWorkflowReference:
    pass
