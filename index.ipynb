# %%
from index.indexer import Indexer
from llm.send import LLMSendToConfig
from llm.openai import send_to_openai, send_to_openai_text_emb

indexer = Indexer(
    final_entities_text_emb_llm_config=LLMSendToConfig(
        llm_send_to=send_to_openai_text_emb,
        llm_model_args={},
    ),
    graph_extractor_llm_config=LLMSendToConfig(
        llm_send_to=send_to_openai,
        llm_model_args={},
    ),
    summarize_extractor_llm_config=LLMSendToConfig(
        llm_send_to=send_to_openai,
        llm_model_args={},
    ),
    community_report_llm_config=LLMSendToConfig(
        llm_send_to=send_to_openai,
        llm_model_args={},
    ),
    output_dir="./index_results",
    doc_saving_dir="./documents",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from index.indexer import Indexer
#       2 from llm.send import LLMSendToConfig
#       3 from llm.openai import send_to_openai, send_to_openai_text_emb
#
# File f:\GitHub\rag-aug\index\indexer.py:3
#       1 import os
#       2 import logging
# ----> 3 import workflow
#       4 import pandas as pd
#       5 import workflow.create_final_communities
#
# File f:\GitHub\rag-aug\workflow\__init__.py:1
# ----> 1 from .create_base_text_units import *
#       2 from .create_base_extracted_entities import *
#       3 from .create_summarized_entities import *
#
# File f:\GitHub\rag-aug\workflow\create_base_text_units.py:2
#       1 from typing import List
# ----> 2 import df_ops
#       3 import pandas as pd
#       4 from utils.save import parquet_table_save
#
# File f:\GitHub\rag-aug\df_ops\__init__.py:4
# ...
