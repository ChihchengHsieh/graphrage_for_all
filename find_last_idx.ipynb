# %%
import pandas as pd

# %%
df = pd.read_csv("augmented-mistral.csv")

# %%
df.iloc[[-1]]
# Out:
#      Unnamed: 0.1  Unnamed: 0           id  \
# 118           118         756  P300R889508
#
#                                          dicom_id  subject_id     stay_id  \
# 118  ce6c73a2-bfbdbdf8-f7f014a2-bfffc5e3-232d2d80    18067737  36661024.0
#
#      study_id  split  eye_tracking_data_discarded gender  ...  \
# 118  58056585  train                        False      M  ...
#
#      Augmented_Collapse or deflation of alveoli in lungs  \
# 118                                               True
#
#      Augmented_Air in pleural space  \
# 118                            True
#
#     Augmented_Disruption of contact between pleurae  \
# 118                                            True
#
#                                       augmenting_query  \
# 118  You are a clinical expert. With following extr...
#
#                                      augmenting_output  \
# 118  {"Shortness of breath": true, "Orthopnea": tru...
#
#      Augmented_Heart rate (beats per minute)  \
# ...

# %%
df.iloc[-1]['id']
# Out:
# 'P300R889508'

# %%
sample_df = pd.read_csv("./spreadsheets/reflacx_clinical.csv")

# %%
sample_df[sample_df['id'] == df.iloc[-1]['id']]
# Out:
#      Unnamed: 0           id                                      dicom_id  \
# 672         756  P300R889508  ce6c73a2-bfbdbdf8-f7f014a2-bfffc5e3-232d2d80
#
#      subject_id     stay_id  study_id  split  eye_tracking_data_discarded  \
# 672    18067737  36661024.0  58056585  train                        False
#
#     gender  anchor_age  ...  temperature heartrate  resprate  o2sat    sbp  \
# 672      M          72  ...         97.6      79.0      20.0  100.0  110.0
#
#       dbp  pain acuity  chiefcomplaint  age
# 672  63.0     4    2.0      R LEG PAIN   77
#
# [1 rows x 80 columns]

# %%
sample_df[sample_df['id'] == df.iloc[-1]['id']].index
# Out:
# Index([672], dtype='int64')

# %%
sample_df.iloc[672]
# Out:
# Unnamed: 0                                                 756
# id                                                 P300R889508
# dicom_id          ce6c73a2-bfbdbdf8-f7f014a2-bfffc5e3-232d2d80
# subject_id                                            18067737
# stay_id                                             36661024.0
#                                       ...
# dbp                                                       63.0
# pain                                                         4
# acuity                                                     2.0
# chiefcomplaint                                      R LEG PAIN
# age                                                         77
# Name: 672, Length: 80, dtype: object
