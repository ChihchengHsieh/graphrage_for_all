# %%
import os
import pandas as pd
import re

# Directory containing the CSV files
directory = '.'

# Pattern to match the CSV files
pattern = re.compile(r'combined-augmented_to(\d+)new\.csv')

# List to store the dataframes
dataframes = []

# Get all files in the directory
files = os.listdir(directory)

# Filter and sort files based on the ending index
sorted_files = sorted(
    [f for f in files if pattern.match(f)],
    key=lambda x: int(pattern.search(x).group(1))
)

# Read each CSV file and append to the list
for file in sorted_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Drop duplicate rows based on the 'Unnamed: 0' column, keeping the first occurrence

# Read the additional CSV file and append its rows to the combined dataframe
missing_df = pd.read_csv('combined-augmented_missingnew.csv')
combined_df = pd.concat([combined_df, missing_df], ignore_index=True)

combined_df = combined_df.drop_duplicates(subset='Unnamed: 0', keep='first')

# Sort the final dataframe using the 'Unnamed: 0' column
combined_df = combined_df.sort_values(by='Unnamed: 0').reset_index(drop=True)

# Save the combined dataframe to a new CSV file
combined_df.to_csv('combined_augmented_all.csv', index=False)

print("CSV files combined successfully into 'combined_augmented_all.csv'")
# Out:
# CSV files combined successfully into 'combined_augmented_all.csv'

# %%
combined_df
# Out:
#      Unnamed: 0.1  Unnamed: 0           id  \
# 0               0           0  P102R108387
# 1               1           1  P102R379837
# 2               2           2  P102R558314
# 3               3           3  P102R765317
# 4               4           4  P102R915878
# ..            ...         ...          ...
# 794            42         898  P300R206615
# 795            43         899  P300R611251
# 796            44         900  P300R519683
# 797            45         901  P300R749452
# 798            46         902  P300R827738
#
#                                          dicom_id  subject_id     stay_id  \
# 0    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 1    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 2    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 3    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 4    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# ..                                            ...         ...         ...
# 794  44572c6e-62135033-45ea19ba-cbea2777-a81fce81    19893236  31661301.0
# 795  2b20dcdf-4077bc16-48fc8eb5-265ef218-f6552cb0    19906407  33352559.0
# 796  92134f99-0e73faba-1280ad81-218c68ba-933a85c5    19907884  39112538.0
# 797  c6db0413-f3266e66-031e9892-2809b536-c13cf9f2    19907884  31819342.0
# 798  bd356a66-7c03720a-c5227633-82282d68-914e93c4    19957626  31501382.0
#
#      study_id  split  eye_tracking_data_discarded gender  ...  \
# 0    55032240  train                        False      F  ...
# 1    55032240    val                        False      F  ...
# 2    55032240    val                        False      F  ...
# 3    55032240  train                        False      F  ...
# 4    55032240  train                        False      F  ...
# ..        ...    ...                          ...    ...  ...
# 794  59220136  train                        False      F  ...
# 795  57296330   test                        False      M  ...
# 796  57427881  train                        False      F  ...
# 797  59325966  train                        False      F  ...
# 798  57835828  train                        False      F  ...
#
#      Augmented_Pleural effusion risk factors (1-5)  \
# 0                                              4.0
# 1                                              4.0
# 2                                              4.0
# 3                                              3.0
# 4                                              4.0
# ..                                             ...
# 794                                            3.0
# 795                                            3.0
# 796                                            3.0
# 797                                            3.0
# 798                                            3.0
#
#      Augmented_Pleural disease risk factors (1-10)  \
# 0                                              8.0
# 1                                              8.0
# 2                                              8.0
# 3                                              5.0
# 4                                              8.0
# ..                                             ...
# 794                                            5.0
# 795                                            5.0
# 796                                            5.0
# 797                                            5.0
# 798                                            5.0
#
#                                       augmenting_query  \
# 0    You are a clinical expert. With following extr...
# 1    You are a clinical expert. With following extr...
# 2    You are a clinical expert. With following extr...
# 3    You are a clinical expert. With following extr...
# 4    You are a clinical expert. With following extr...
# ..                                                 ...
# 794  You are a clinical expert. With following extr...
# 795  You are a clinical expert. With following extr...
# 796  You are a clinical expert. With following extr...
# 797  You are a clinical expert. With following extr...
# 798  You are a clinical expert. With following extr...
#
#                                      augmenting_output  \
# 0    {"Shortness of breath": true, "Fatigue": true,...
# 1    {"Shortness of breath": true, "Fatigue": true,...
# 2    {"Shortness of breath": true, "Fatigue": true,...
# 3    {"Shortness of breath": false, "Fatigue": fals...
# 4    {"Shortness of breath": true, "Fatigue": true,...
# ..                                                 ...
# 794  {"Shortness of breath": false, "Fatigue": fals...
# 795  {"Shortness of breath": false, "Fatigue": fals...
# 796  {"Shortness of breath": true, "Fatigue": true,...
# 797  {"Shortness of breath": false, "Fatigue": fals...
# 798  {"Shortness of breath": false, "Fatigue": fals...
#
#      Augmented_History of COPD  Augmented_Age  Augmented_Heartrate  \
# 0                          NaN            NaN                  NaN
# 1                          NaN            NaN                  NaN
# 2                          NaN            NaN                  NaN
# 3                          NaN            NaN                  NaN
# 4                          NaN            NaN                  NaN
# ..                         ...            ...                  ...
# 794                        NaN            NaN                  NaN
# 795                        NaN            NaN                  NaN
# 796                        NaN            NaN                  NaN
# 797                        NaN            NaN                  NaN
# 798                        NaN            NaN                  NaN
#
#      Augmented_Oxygen levels (%) Augmented_Importance Score  Augmented_Data
# 0                            NaN                        NaN             NaN
# 1                            NaN                        NaN             NaN
# 2                            NaN                        NaN             NaN
# 3                            NaN                        NaN             NaN
# 4                            NaN                        NaN             NaN
# ..                           ...                        ...             ...
# 794                          NaN                        NaN             NaN
# 795                          NaN                        NaN             NaN
# 796                          NaN                        NaN             NaN
# 797                          NaN                        NaN             NaN
# 798                          NaN                        NaN             NaN
#
# [799 rows x 195 columns]

# %%
sample_df = pd.read_csv("./spreadsheets/reflacx_clinical.csv")

# %%
generated_idx = combined_df["Unnamed: 0"].tolist()

# %%
[(idx)for idx, id in enumerate(sample_df["Unnamed: 0"].tolist()) if id not in generated_idx]
# Out:
# [30, 31, 32, 33, 34, 414, 431, 445, 446, 447, 464]

# %%
combined_df
# Out:
#      Unnamed: 0.1  Unnamed: 0           id  \
# 0               0           0  P102R108387
# 1               1           1  P102R379837
# 2               2           2  P102R558314
# 3               3           3  P102R765317
# 4               4           4  P102R915878
# ..            ...         ...          ...
# 724            42         898  P300R206615
# 725            43         899  P300R611251
# 726            44         900  P300R519683
# 727            45         901  P300R749452
# 728            46         902  P300R827738
#
#                                          dicom_id  subject_id     stay_id  \
# 0    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 1    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 2    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 3    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# 4    34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516  32067002.0
# ..                                            ...         ...         ...
# 724  44572c6e-62135033-45ea19ba-cbea2777-a81fce81    19893236  31661301.0
# 725  2b20dcdf-4077bc16-48fc8eb5-265ef218-f6552cb0    19906407  33352559.0
# 726  92134f99-0e73faba-1280ad81-218c68ba-933a85c5    19907884  39112538.0
# 727  c6db0413-f3266e66-031e9892-2809b536-c13cf9f2    19907884  31819342.0
# 728  bd356a66-7c03720a-c5227633-82282d68-914e93c4    19957626  31501382.0
#
#      study_id  split  eye_tracking_data_discarded gender  ...  \
# 0    55032240  train                        False      F  ...
# 1    55032240    val                        False      F  ...
# 2    55032240    val                        False      F  ...
# 3    55032240  train                        False      F  ...
# 4    55032240  train                        False      F  ...
# ..        ...    ...                          ...    ...  ...
# 724  59220136  train                        False      F  ...
# 725  57296330   test                        False      M  ...
# 726  57427881  train                        False      F  ...
# 727  59325966  train                        False      F  ...
# 728  57835828  train                        False      F  ...
#
#      Augmented_Chest radiography  Augmented_Computed tomography (CT) scans  \
# 0                           True                                      True
# 1                           True                                      True
# 2                           True                                      True
# 3                          False                                     False
# 4                           True                                      True
# ..                           ...                                       ...
# 724                        False                                     False
# 725                        False                                     False
# 726                        False                                     False
# 727                        False                                     False
# 728                        False                                     False
#
#     Augmented_Pulmonary function tests  Augmented_Heart failure  \
# 0                                 True                     True
# 1                                 True                     True
# 2                                 True                     True
# 3                                False                    False
# 4                                 True                     True
# ..                                 ...                      ...
# 724                              False                    False
# 725                              False                    False
# 726                              False                    False
# 727                              False                    False
# 728                              False                    False
#
#      Augmented_Perforation of the intestine  Augmented_Surgical procedure  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                          True
# 3                                     False                         False
# 4                                      True                          True
# ..                                      ...                           ...
# 724                                   False                         False
# 725                                   False                         False
# 726                                   False                         False
# 727                                   False                         False
# 728                                   False                         False
#
#      Augmented_Pleural effusion risk factors (1-5)  \
# 0                                                4
# 1                                                4
# 2                                                4
# 3                                                3
# 4                                                4
# ..                                             ...
# 724                                              3
# 725                                              3
# 726                                              3
# 727                                              3
# 728                                              3
#
#      Augmented_Pleural disease risk factors (1-10)  \
# 0                                                8
# 1                                                8
# 2                                                8
# 3                                                5
# 4                                                8
# ..                                             ...
# 724                                              5
# 725                                              5
# 726                                              5
# 727                                              5
# 728                                              5
#
#                                       augmenting_query  \
# 0    You are a clinical expert. With following extr...
# 1    You are a clinical expert. With following extr...
# 2    You are a clinical expert. With following extr...
# 3    You are a clinical expert. With following extr...
# 4    You are a clinical expert. With following extr...
# ..                                                 ...
# 724  You are a clinical expert. With following extr...
# 725  You are a clinical expert. With following extr...
# 726  You are a clinical expert. With following extr...
# 727  You are a clinical expert. With following extr...
# 728  You are a clinical expert. With following extr...
#
#                                      augmenting_output
# 0    {"Shortness of breath": true, "Fatigue": true,...
# 1    {"Shortness of breath": true, "Fatigue": true,...
# 2    {"Shortness of breath": true, "Fatigue": true,...
# 3    {"Shortness of breath": false, "Fatigue": fals...
# 4    {"Shortness of breath": true, "Fatigue": true,...
# ..                                                 ...
# 724  {"Shortness of breath": false, "Fatigue": fals...
# 725  {"Shortness of breath": false, "Fatigue": fals...
# 726  {"Shortness of breath": true, "Fatigue": true,...
# 727  {"Shortness of breath": false, "Fatigue": fals...
# 728  {"Shortness of breath": false, "Fatigue": fals...
#
# [729 rows x 189 columns]

# %%
sorted_files
# Out:
# ['combined-augmented_to22new.csv',
#  'combined-augmented_to41new.csv',
#  'combined-augmented_to73new.csv',
#  'combined-augmented_to92new.csv',
#  'combined-augmented_to102new.csv',
#  'combined-augmented_to124new.csv',
#  'combined-augmented_to185new.csv',
#  'combined-augmented_to192new.csv',
#  'combined-augmented_to252new.csv',
#  'combined-augmented_to289new.csv',
#  'combined-augmented_to303new.csv',
#  'combined-augmented_to350new.csv',
#  'combined-augmented_to408new.csv',
#  'combined-augmented_to414new.csv',
#  'combined-augmented_to464new.csv',
#  'combined-augmented_to527new.csv',
#  'combined-augmented_to658new.csv',
#  'combined-augmented_to700new.csv',
#  'combined-augmented_to752new.csv',
#  'combined-augmented_to799new.csv']

# %%
import os
import pandas as pd
import re

# Directory containing the CSV files
directory = '.'

# Pattern to match the CSV files
pattern = re.compile(r'combined-augmented_to(\d+)_nodb\.csv')

# List to store the dataframes
dataframes = []

# Get all files in the directory
files = os.listdir(directory)

# Filter and sort files based on the ending index
sorted_files = sorted(
    [f for f in files if pattern.match(f)],
    key=lambda x: int(pattern.search(x).group(1))
)

# Read each CSV file and append to the list
for file in sorted_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_df.to_csv('combined_augmented_all_nodb.csv', index=False)

print("CSV files combined successfully into 'combined_augmented_all_nodb.csv'")
# Out:
# CSV files combined successfully into 'combined_augmented_all.csv'

# %%
# for mistral with DB

import os
import pandas as pd
import re

# Directory containing the CSV files
directory = '.'
# augmented-mistral-to185
# Pattern to match the CSV files
pattern = re.compile(r'augmented-mistral-to(\d+)\.csv')

# List to store the dataframes
dataframes = []

# Get all files in the directory
files = os.listdir(directory)

# Filter and sort files based on the ending index
sorted_files = sorted(
    [f for f in files if pattern.match(f)],
    key=lambda x: int(pattern.search(x).group(1))
)

# Read each CSV file and append to the list
for file in sorted_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_df.to_csv('combined_augmented_mistral.csv', index=False)

print("CSV files combined successfully into 'combined_augmented_all_nodb.csv'")

# %%
combined_df = pd.read_csv('combined_augmented_mistral.csv')

# %%
799-679
# Out:
# 120

# %%
len(combined_df)
# Out:
# 679

# %%
# for mistral without DB

import os
import pandas as pd
import re

# Directory containing the CSV files
directory = '.'
# augmented-mistral-to185
# Pattern to match the CSV files
pattern = re.compile(r'augmented-mistral-nodb-to(\d+)\.csv')

# List to store the dataframes
dataframes = []

# Get all files in the directory
files = os.listdir(directory)

# Filter and sort files based on the ending index
sorted_files = sorted(
    [f for f in files if pattern.match(f)],
    key=lambda x: int(pattern.search(x).group(1))
)

# Read each CSV file and append to the list
for file in sorted_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_df.to_csv('combined_augmented_mistral_nodb.csv', index=False)

print("CSV files combined successfully into 'combined_augmented_all_nodb.csv'")
# Out:
# CSV files combined successfully into 'combined_augmented_all_nodb.csv'

# %%
799- len(combined_df)
# Out:
# 228

# %%
# 120 -> with DB
# 228 -> no db

# %% [markdown]
# | Model | Using Storage | Not Using Storage |
# |---|---|---|
# |LLama 3.1 8B | 0 | 0 |
# |Mistral 7B | 120 | 228 |
